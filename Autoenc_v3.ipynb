# %%
# import packages
# matplotlib inline
import pandas as pd
import numpy as np
from scipy import stats
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
import pickle
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, precision_recall_curve
from sklearn.metrics import recall_score, classification_report, auc, roc_curve
from sklearn.metrics import precision_recall_fscore_support, f1_score
from sklearn.preprocessing import StandardScaler
from pylab import rcParams
from keras.models import Model, load_model
from keras.layers import Input, Dense
from keras.callbacks import ModelCheckpoint, TensorBoard
from keras import regularizers

#ustawiam ziarno pseudolosowania i udział zbioru testowego
RANDOM_SEED = 128262 
TEST_PCT = 0.2 

#set up graphic style in this case I am using the color scheme from xkcd.com
rcParams['figure.figsize'] = 14, 8.7 # złoty podział
LABELS = ["Normal","Fraud"]

# %%
df = pd.read_csv("creditcard.csv")

# %%
col_list = ["cerulean","scarlet"]# https://xkcd.com/color/rgb/
sns.set(style='white', font_scale=1.75)
sns.set_palette(sns.xkcd_palette(col_list))

# %% [markdown]
# Normalize and Scale Data

# %%
df_norm = df.copy()
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature
# or array.reshape(1, -1) if it contains a single sample.
df_norm['Time'] = StandardScaler().fit_transform(df_norm['Time'].values.reshape(-1, 1))
df_norm['Amount'] = StandardScaler().fit_transform(df_norm['Amount'].values.reshape(-1, 1))

# %% [markdown]
# Dividing Training and Test Set

# %%
train_x, test_x = train_test_split(df_norm, test_size=TEST_PCT, random_state=RANDOM_SEED)
train_x = train_x[train_x.Class == 0]       # where normal transactions
train_x = train_x.drop(['Class'], axis=1)   # drop the class column


test_y = test_x['Class']                    # save the class column for the test set
test_x = test_x.drop(['Class'], axis=1)     # drop the class column

train_x = train_x.values                    # transform to ndarray
test_x = test_x.values                      # transform to ndarray

# %%
df_norm.shape
# Out:
# (284807, 31)

# %% [markdown]
# Creating The Mode

# %%
# Autoencoder Layer Structure and Parameters

nb_epoch = 50
batch_size = 64
input_dim = train_x.shape[1] #num of columns, 30
encoding_dim = 20
hidden_dim2 = 8
learning_rate = 1e-7

# %%
# This returns a tensor
input_layer = Input(shape=(input_dim, ))

# a layer instance is callable on a tensor, and returns a tensor
# Dense implements the operation: output = activation(dot(input, kernel) + bias), where
# activation is the element-wise activation function passed as the activation argument, 
# kernel is a weights matrix created by the layer, and 
# bias is a bias vector created by the layer (only applicable if use_bias is True).

# activity_regularizer: Regularizer function applied to the output of the layer
encoder = Dense(encoding_dim, activation="tanh", 
                activity_regularizer=regularizers.l1(learning_rate))(input_layer)
encoder = Dense(hidden_dim2, activation="relu")(encoder)
decoder = Dense(hidden_dim2, activation='relu')(encoder)
decoder = Dense(input_dim, activation='relu')(decoder)

# This creates a model that includes
# the Input layer and four Dense layers
autoencoder = Model(inputs=input_layer, outputs=decoder)

# %%
# Configure the learning process, by compiling the model
autoencoder.compile(optimizer='adam',
                    metrics=['accuracy'],
                    loss='mean_squared_error')

# Saving the model
cp = ModelCheckpoint(filepath="autoencoder_fraud.h5",
                     save_best_only=True,
                     verbose=0)

# TensorBoard basic visualizations.
# This callback writes a log for TensorBoard, 
# which allows you to visualize dynamic graphs of your training and test metrics
tb = TensorBoard(log_dir='./logs',
                 histogram_freq=0,
                 write_graph=True,
                 write_images=True)

# Starts training
# autoencoder: same training(x) and target data(y)
# validation_data: tuple (x_val, y_val) on which 
# to evaluate the loss and any model metrics at the end of each epoch.

# History.history attribute is a record of training loss values 
# and metrics values at successive epochs.
history = autoencoder.fit(x=train_x, y=train_x,
                          epochs=nb_epoch,
                          batch_size=batch_size,
                          shuffle=True,
                          validation_data=(test_x, test_x),
                          verbose=1,
                          callbacks=[cp, tb]).history
# Out:
# Epoch 1/50
# 3554/3554 [==============================] - 3s 862us/step - loss: 0.7968 - accuracy: 0.5801 - val_loss: 0.7650 - val_accuracy: 0.6610
# Epoch 2/50
# 3554/3554 [==============================] - 3s 815us/step - loss: 0.7213 - accuracy: 0.6638 - val_loss: 0.7458 - val_accuracy: 0.6713
# Epoch 3/50
# 3554/3554 [==============================] - 3s 805us/step - loss: 0.7091 - accuracy: 0.6784 - val_loss: 0.7394 - val_accuracy: 0.6840
# Epoch 4/50
# 3554/3554 [==============================] - 3s 787us/step - loss: 0.7039 - accuracy: 0.6871 - val_loss: 0.7353 - val_accuracy: 0.6895
# Epoch 5/50
# 3554/3554 [==============================] - 3s 798us/step - loss: 0.7011 - accuracy: 0.6916 - val_loss: 0.7331 - val_accuracy: 0.6957
# Epoch 6/50
# 3554/3554 [==============================] - 3s 828us/step - loss: 0.6993 - accuracy: 0.6951 - val_loss: 0.7326 - val_accuracy: 0.6954
# Epoch 7/50
# 3554/3554 [==============================] - 3s 792us/step - loss: 0.6983 - accuracy: 0.6935 - val_loss: 0.7311 - val_accuracy: 0.6909
# Epoch 8/50
# 3554/3554 [==============================] - 3s 797us/step - loss: 0.6973 - accuracy: 0.6936 - val_loss: 0.7302 - val_accuracy: 0.6950
# Epoch 9/50
# 3554/3554 [==============================] - 3s 787us/step - loss: 0.6965 - accuracy: 0.6938 - val_loss: 0.7365 - val_accuracy: 0.6845
# Epoch 10/50
# 3554/3554 [==============================] - 3s 790us/step - loss: 0.6961 - accuracy: 0.6949 - val_loss: 0.7282 - val_accuracy: 0.6960
# Epoch 11/50
# 3554/3554 [==============================] - 3s 786us/step - loss: 0.6955 - accuracy: 0.6958 - val_loss: 0.7276 - val_accuracy: 0.6918
# Epoch 12/50
# 3554/3554 [==============================] - 3s 817us/step - loss: 0.6949 - accuracy: 0.6964 - val_loss: 0.7266 - val_accuracy: 0.6984
# Epoch 13/50
# 3554/3554 [==============================] - 3s 802us/step - loss: 0.6948 - accuracy: 0.6975 - val_loss: 0.7265 - val_accuracy: 0.6991
# Epoch 14/50
# 3554/3554 [==============================] - 3s 790us/step - loss: 0.6942 - accuracy: 0.6980 - val_loss: 0.7330 - val_accuracy: 0.6964
# Epoch 15/50
# 3554/3554 [==============================] - 3s 792us/step - loss: 0.6937 - accuracy: 0.6973 - val_loss: 0.7270 - val_accuracy: 0.6951
# Epoch 16/50
# 3554/3554 [==============================] - 3s 802us/step - loss: 0.6944 - accuracy: 0.6976 - val_loss: 0.7253 - val_accuracy: 0.7008
# Epoch 17/50
# 3554/3554 [==============================] - 3s 795us/step - loss: 0.6938 - accuracy: 0.6971 - val_loss: 0.7259 - val_accuracy: 0.7003
# Epoch 18/50
# 3554/3554 [==============================] - 3s 815us/step - loss: 0.6933 - accuracy: 0.6964 - val_loss: 0.7272 - val_accuracy: 0.6962
# Epoch 19/50
# 3554/3554 [==============================] - 3s 816us/step - loss: 0.6932 - accuracy: 0.6969 - val_loss: 0.7248 - val_accuracy: 0.6961
# Epoch 20/50
# 3554/3554 [==============================] - 3s 798us/step - loss: 0.6930 - accuracy: 0.6964 - val_loss: 0.7247 - val_accuracy: 0.7033
# Epoch 21/50
# 3554/3554 [==============================] - 3s 795us/step - loss: 0.6932 - accuracy: 0.6974 - val_loss: 0.7268 - val_accuracy: 0.6986
# Epoch 22/50
# 3554/3554 [==============================] - 3s 789us/step - loss: 0.6924 - accuracy: 0.6984 - val_loss: 0.7251 - val_accuracy: 0.6981
# Epoch 23/50
# 3554/3554 [==============================] - 3s 808us/step - loss: 0.6924 - accuracy: 0.6980 - val_loss: 0.7246 - val_accuracy: 0.6957
# Epoch 24/50
# 3554/3554 [==============================] - 3s 800us/step - loss: 0.6921 - accuracy: 0.6983 - val_loss: 0.7246 - val_accuracy: 0.7020
# Epoch 25/50
# 3554/3554 [==============================] - 3s 805us/step - loss: 0.6921 - accuracy: 0.6984 - val_loss: 0.7255 - val_accuracy: 0.7028
# Epoch 26/50
# 3554/3554 [==============================] - 3s 792us/step - loss: 0.6919 - accuracy: 0.6991 - val_loss: 0.7249 - val_accuracy: 0.6987
# Epoch 27/50
# 3554/3554 [==============================] - 3s 794us/step - loss: 0.6919 - accuracy: 0.6998 - val_loss: 0.7263 - val_accuracy: 0.7003
# Epoch 28/50
# 3554/3554 [==============================] - 3s 785us/step - loss: 0.6916 - accuracy: 0.6996 - val_loss: 0.7265 - val_accuracy: 0.7035
# Epoch 29/50
# 3554/3554 [==============================] - 3s 819us/step - loss: 0.6915 - accuracy: 0.7001 - val_loss: 0.7236 - val_accuracy: 0.6971
# Epoch 30/50
# 3554/3554 [==============================] - 3s 812us/step - loss: 0.6914 - accuracy: 0.6999 - val_loss: 0.7245 - val_accuracy: 0.6978
# Epoch 31/50
# 3554/3554 [==============================] - 3s 795us/step - loss: 0.6919 - accuracy: 0.6993 - val_loss: 0.7252 - val_accuracy: 0.7021
# Epoch 32/50
# 3554/3554 [==============================] - 3s 783us/step - loss: 0.6912 - accuracy: 0.7004 - val_loss: 0.7337 - val_accuracy: 0.7038
# Epoch 33/50
# 3554/3554 [==============================] - 3s 790us/step - loss: 0.6916 - accuracy: 0.7014 - val_loss: 0.7247 - val_accuracy: 0.7014
# Epoch 34/50
# 3554/3554 [==============================] - 3s 801us/step - loss: 0.6914 - accuracy: 0.6999 - val_loss: 0.7229 - val_accuracy: 0.7033
# Epoch 35/50
# 3554/3554 [==============================] - 3s 817us/step - loss: 0.6913 - accuracy: 0.7006 - val_loss: 0.7242 - val_accuracy: 0.6992
# Epoch 36/50
# 3554/3554 [==============================] - 3s 796us/step - loss: 0.6906 - accuracy: 0.7004 - val_loss: 0.7234 - val_accuracy: 0.6993
# Epoch 37/50
# 3554/3554 [==============================] - 3s 797us/step - loss: 0.6911 - accuracy: 0.7003 - val_loss: 0.7230 - val_accuracy: 0.7042
# Epoch 38/50
# 3554/3554 [==============================] - 3s 811us/step - loss: 0.6909 - accuracy: 0.6998 - val_loss: 0.7230 - val_accuracy: 0.7024
# Epoch 39/50
# 3554/3554 [==============================] - 3s 802us/step - loss: 0.6906 - accuracy: 0.7008 - val_loss: 0.7229 - val_accuracy: 0.7022
# Epoch 40/50
# 3554/3554 [==============================] - 3s 828us/step - loss: 0.6909 - accuracy: 0.6994 - val_loss: 0.7227 - val_accuracy: 0.7058
# Epoch 41/50
# 3554/3554 [==============================] - 3s 800us/step - loss: 0.6904 - accuracy: 0.6995 - val_loss: 0.7234 - val_accuracy: 0.7020
# Epoch 42/50
# 3554/3554 [==============================] - 3s 798us/step - loss: 0.6901 - accuracy: 0.6998 - val_loss: 0.7222 - val_accuracy: 0.7037
# Epoch 43/50
# 3554/3554 [==============================] - 3s 808us/step - loss: 0.6902 - accuracy: 0.6993 - val_loss: 0.7232 - val_accuracy: 0.7009
# Epoch 44/50
# 3554/3554 [==============================] - 3s 794us/step - loss: 0.6900 - accuracy: 0.6981 - val_loss: 0.7227 - val_accuracy: 0.7025
# Epoch 45/50
# 3554/3554 [==============================] - 3s 814us/step - loss: 0.6900 - accuracy: 0.6992 - val_loss: 0.7255 - val_accuracy: 0.6976
# Epoch 46/50
# 3554/3554 [==============================] - 3s 820us/step - loss: 0.6914 - accuracy: 0.6976 - val_loss: 0.7263 - val_accuracy: 0.6931
# Epoch 47/50
# 3554/3554 [==============================] - 3s 800us/step - loss: 0.6897 - accuracy: 0.6983 - val_loss: 0.7235 - val_accuracy: 0.7013
# Epoch 48/50
# 3554/3554 [==============================] - 3s 805us/step - loss: 0.6908 - accuracy: 0.6991 - val_loss: 0.7234 - val_accuracy: 0.7012
# Epoch 49/50
# 3554/3554 [==============================] - 3s 793us/step - loss: 0.6901 - accuracy: 0.6985 - val_loss: 0.7237 - val_accuracy: 0.7004
# Epoch 50/50
# 3554/3554 [==============================] - 3s 802us/step - loss: 0.6901 - accuracy: 0.6992 - val_loss: 0.7231 - val_accuracy: 0.7010

# %%
autoencoder = load_model('autoencoder_fraud.h5')

# %% [markdown]
# Model Evaluation

# %%
plt.figure(figsize=(14, 8))
plt.plot(history['loss'], linewidth=2, label='Train')
plt.plot(history['val_loss'], linewidth=2, label='Test')
plt.legend(loc='upper right')
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
#plt.ylim(ymin=0.70,ymax=1)
plt.show()

# %% [markdown]
# Reconstruction Error Check

# %%
test_x_predictions = autoencoder.predict(test_x)
mse = np.mean(np.power(test_x - test_x_predictions, 2), axis=1)
error_df = pd.DataFrame({'Reconstruction_error': mse,
                        'True_class': test_y})
error_df.describe()
# Out:
#        Reconstruction_error    True_class
# count          56962.000000  56962.000000
# mean               0.722213      0.001668
# std                3.274567      0.040805
# min                0.041560      0.000000
# 25%                0.257394      0.000000
# 50%                0.406107      0.000000
# 75%                0.626830      0.000000
# max              390.875908      1.000000

# %% [markdown]
# ROC Curve Check

# %%
false_pos_rate, true_pos_rate, thresholds = roc_curve(error_df.True_class,
                                                      error_df.Reconstruction_error)
roc_auc = auc(false_pos_rate, true_pos_rate,)

plt.figure(figsize=(14, 8))
plt.plot(false_pos_rate, true_pos_rate, linewidth=2, label='AUC = %0.3f'% roc_auc)
plt.plot([0,1],[0,1], linewidth=2)

plt.xlim([-0.01, 1])
plt.ylim([0, 1.01])
plt.legend(loc='lower right')
plt.title('Receiver operating characteristic curve (ROC)')
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %% [markdown]
# Recall vs. Precision Thresholding

# %%
# calculates precision/recall using reconstruction error as the decision function
# returns: 
# precision_rt: Precision values such that element i is the precision of predictions with 
#               score >= thresholds[i] and the last element is 1.
# recall_rt: Decreasing recall values such that element i is the recall of predictions with 
#           score >= thresholds[i] and the last element is 0.
# threshold_rt = Increasing thresholds on the decision function used to compute
#                precision and recall.
precision_rt, recall_rt, threshold_rt = precision_recall_curve(error_df.True_class,
                                                               error_df.Reconstruction_error)

pr_auc = auc(recall_rt, precision_rt,)

plt.figure(figsize=(14, 8))
plt.plot(recall_rt, precision_rt, linewidth=2, label='AUC = %0.3f'% pr_auc)
plt.legend(loc='upper right')
plt.title('Recall vs Precision')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.show()

# %%
plt.figure(figsize=(14, 8))
plt.plot(threshold_rt, precision_rt[1:], label="Precision",linewidth=2)
plt.plot(threshold_rt, recall_rt[1:], label="Recall",linewidth=2)
plt.title('Precision and recall for different threshold values')
plt.xlabel('Threshold')
plt.ylabel('Precision/Recall')
plt.legend()
plt.show()

# %% [markdown]
# Reconstruction Error vs Threshold Check

# %%
threshold_fixed = 4
groups = error_df.groupby('True_class')
fig, ax = plt.subplots(figsize=(14, 8))

for name, group in groups:
    ax.plot(group.index, group.Reconstruction_error, marker='o', ms=3.5, linestyle='',
            label= "Fraud" if name == 1 else "Normal")
ax.hlines(threshold_fixed, ax.get_xlim()[0], ax.get_xlim()[1],
          colors="r", zorder=100, label='Threshold')
ax.legend()
plt.title("Reconstruction error for different classes")
plt.ylabel("Reconstruction error")
plt.xlabel("Data point index")
plt.show();

# %% [markdown]
# Confusion Matrix

# %%
 #As with autoencoders, it is the assumption that fraud or anomalies will suffer 
# from a detectably high reconstruction error, predicting class as 1 (Fraud)
# if reconstruction error is greater than threshold
pred_y = [1 if e > threshold_fixed else 0 for e in error_df.Reconstruction_error.values]
conf_matrix = confusion_matrix(error_df.True_class, pred_y)

plt.figure(figsize=(12, 12))
sns.heatmap(conf_matrix, xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt="d");
plt.title("Confusion matrix")
plt.ylabel('True class')
plt.xlabel('Predicted class')
plt.show()
